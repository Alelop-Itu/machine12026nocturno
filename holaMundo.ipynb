# %% [markdown]
# ![Logo del Instituto](https://raw.githubusercontent.com/Alelop-Itu/machine12026nocturno/refs/heads/main/img/logoitqv1.jpg)

# %% [markdown]
# ![Logo de Python](https://raw.githubusercontent.com/Alelop-Itu/machine12026nocturno/refs/heads/main/img/python_logo.png)

# %% [markdown]
# # Primer programa en Python
# ## Hola mundo desde Python
# * Nombre: Alejandra López
# * Fecha: **23-06-2026**
# * Repositorio: <a href="https://github.com/Alelop-Itu/machine12026nocturno.git"> Link del reposotorio de Github</a>

# %% [markdown]
# Esta sección es para crear una función lambda donde calculo la raíz de un número

# %%
# Comentario en python saludando desde Python
print("Hola mundo desde Python")
# Out:
# Hola mundo desde Python
