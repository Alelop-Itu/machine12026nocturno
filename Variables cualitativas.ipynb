# %% [markdown]
# ![Logo del Instituto](https://raw.githubusercontent.com/Alelop-Itu/machine12026nocturno/refs/heads/main/img/logoitqv1.jpg)

# %% [markdown]
# # 01PAO26-26 - Variables cualitativas

# %% [markdown]
# ![Logo de Python](https://raw.githubusercontent.com/Alelop-Itu/machine12026nocturno/refs/heads/main/img/python_logo.png)

# %% [markdown]
# * Nombre: Alejandra López
# * Fecha: **14-07-2026**
# * Repositorio: [Link del repositorio de Github](https://github.com/Alelop-Itu/machine12026nocturno.git)

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)
nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Doctorado'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Master' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Doctorado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Master' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Doctorado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Doctorado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Secundaria'
#  'Master' 'Master' 'Secundaria' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Master' 'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Doctorado' 'Grado'
#  'Grado' 'Doctorado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Master'
#  'Grado' 'Doctorado' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Secundaria' 'Bachillerato' 'Doctorado' 'Grado' 'Grado' 'Grado'
#  'Master' 'Master' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Bachillerato' 'Master'
#  'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Secundaria' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Doctorado'
#  'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Master' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Master'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Master' 'Doctorado' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Master'
#  'Grado' 'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Master' 'Secundaria'
#  'Master' 'Master' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Doctorado' 'Grado' 'Master' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Doctorado' 'Master' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato' 'Grado' 'Master'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 1. Definir los datos
data = {
    'Nivel': ['Bachillerato', 'Doctorado', 'Grado', 'Master', 'Secundaria'],
    'Frecuencia': [172, 21, 145, 52, 110]}

# %%
# 2. Crear el DataFrame
df = pd.DataFrame(data)

# %%
# 3. Diagrama de barras con pandas
df.plot(kind='bar', x='Nivel', y='Frecuencia', legend=False, title='Diagrama de barras')
plt.ylabel('Frecuencia absoluta')
plt.show()

# %%
# 4. Diagrama de sectores con pandas
df.plot(kind='pie', y='Frecuencia', labels=df['Nivel'], autopct='%1.2f%%', title='Diagrama de sectores', legend=False)
plt.ylabel('') # Oculta la etiqueta del eje Y que aparece por defecto en pandas
plt.show()
